# %%
import keras
import tensorflow as tf
import matplotlib.pyplot as plt

# %%
import mnist_reader
X_train, y_train = mnist_reader.load_mnist('data/fashion', kind='train')
X_test, y_test = mnist_reader.load_mnist('data/fashion', kind='t10k')

# %%
X_train = X_train / 255.0
X_test = X_test / 255.0

X_test.shape
# Out:
# (10000, 784)

# %%
model = keras.Sequential([
    keras.layers.Dense(128, activation=tf.nn.relu),
    keras.layers.Dense(10, activation=tf.nn.softmax)
])
model.compile(optimizer='adam', 
              loss='sparse_categorical_crossentropy',
              metrics=['accuracy'])

# %%
model.fit(X_train, y_train, epochs=10)
# Out:
# Epoch 1/10
# 60000/60000 [==============================] - 5s 81us/step - loss: 2.3028 - acc: 0.0991
# Epoch 2/10
# 60000/60000 [==============================] - 5s 77us/step - loss: 2.3028 - acc: 0.0987
# Epoch 3/10
# 60000/60000 [==============================] - 5s 79us/step - loss: 2.3028 - acc: 0.0975
# Epoch 4/10
# 60000/60000 [==============================] - 5s 79us/step - loss: 2.3028 - acc: 0.0994
# Epoch 5/10
# 60000/60000 [==============================] - 5s 77us/step - loss: 2.3028 - acc: 0.0986
# Epoch 6/10
# 60000/60000 [==============================] - 4s 73us/step - loss: 2.3028 - acc: 0.0975
# Epoch 7/10
# 60000/60000 [==============================] - 4s 74us/step - loss: 2.3028 - acc: 0.0980
# Epoch 8/10
# 60000/60000 [==============================] - 4s 73us/step - loss: 2.3028 - acc: 0.0991
# Epoch 9/10
# 60000/60000 [==============================] - 5s 75us/step - loss: 2.3028 - acc: 0.0985
# Epoch 10/10
# 60000/60000 [==============================] - 4s 74us/step - loss: 2.3028 - acc: 0.0971

# %%
test_loss, test_acc = model.evaluate(X_test, y_test)
print('Test accuracy:', test_acc)
# Out:
# 10000/10000 [==============================] - 0s 47us/step
# Test accuracy: 0.1

# %%
import cv2
import glob
images = [cv2.imread(file) for file in glob.glob('dataset/*png')]

# %%
import numpy as np
np.array(images[0][]).shape
# Out:
# (374, 3)

# %%
plt.figure()
plt.imshow(images[0],cmap='gray')
plt.colorbar()
plt.grid()
plt.show()
